# %%
# Strings -- "",'', """""", str() --> Set of characters/Array of characters(a-z or A-Z).

# %%
My_Name = "Abhishek"
print(type(My_Name))
print(My_Name)
# Out:
# <class 'str'>
# Abhishek

# %%
# Problem -- 
msg = ""Abhishek"got 80 marks in maths."
print(msg)
# Out:
#   Cell In[4], line 2
#     msg = ""Abhishek"got 80 marks in maths."
#             ^
# SyntaxError: invalid syntax

# %%
# first way :-
# msg = '"Abhishek" got 80 marks in maths.'

# 2nd way
# msg = "\"Amit\" got 80 marks in maths."

# 3rd way
msg = '\'Aditya\' got 80 marks in maths.'
print(msg)
# Out:
# 'Aditya' got 80 marks in maths.

# %%
print("It's alright")
print("He is called 'Johnny'")
print('He is called "Johnny"')
# Out:
# It's alright
# He is called 'Johnny'
# He is called "Johnny"

# %%
print(My_Name[0]) # left to right --- +ve indexing
print(My_Name[-8]) # Right to left -- -ve indexing
# Out:
# A
# A

# %%
# Loop Through String
for i in My_Name:
    print(i)
# Out:
# A
# b
# h
# i
# s
# h
# e
# k

# %%
print(len(My_Name))
# Out:
# 8

# %%
print("i" in My_Name)
# Out:
# True

# %%
print("80" in msg)
# Out:
# True

# %%
print("80" not in msg)
# Out:
# False

# %% [markdown]
# ## Slicing --> [Start:End] --> Start is going to include in my string and End will be excluded.

# %%
# Indexing from left -- Positive Indexing
print(My_Name[:4])
print(My_Name[0:4])
# Out:
# Abhi
# Abhi

# %%
# Indexing from Right -- Negative Indexing
print(My_Name[:-4])
print(My_Name[-8:-4])
# Out:
# Abhi
# Abhi

# %%
print(My_Name[4:])
print(My_Name[4:8])
# Out:
# shek
# shek

# %%
My_Name
# Out:
# 'Abhishek'

# %%
My_Name.lower()
# Out:
# 'abhishek'

# %%
My_Name.upper()
# Out:
# 'ABHISHEK'

# %%
mY_nAme = '       Manish     '
mY_nAme
# Out:
# '       Manish     '

# %%
mY_nAme = mY_nAme.strip()

# %%
mY_nAme
# Out:
# 'Manish'

# %%
My_Name
# Out:
# 'Abhishek'

# %%
text = "Hello My Name is Manish."
len(text)
# Out:
# 24

# %%
text.replace("H","J")
# Out:
# 'Jello My Name is Manish.'

# %%
a = "Hello, World!"
print(a.split(","))
# Out:
# ['Hello', ' World!']

# %%
text.split(" ")
# Out:
# ['Hello', 'My', 'Name', 'is', 'Manish.']

# %%
# Placeholders and Modifiers
# A placeholder can contain variables, operations, functions, and modifiers to format the value.
# A placeholder can include a modifier to format the value.
# A modifier is included by adding a colon : followed by a legal formatting type, like .2f which means fixed point number with 2 decimals

# %%
price = 59
txt = f"The price is {price:.2f} dollars"
print(txt)
# Out:
# The price is 59.00 dollars

# %%
print("Hello, World!")
print("Hello, World!")
print("Hello, World!")
# Out:
# Hello, World!
# Hello, World!
# Hello, World!

# %%
print("Hello, World!\nHello, World!\nHello, World!")
# Out:
# Hello, World!
# Hello, World!
# Hello, World!

# %%
print("Hello, World! Hello, World! Hello, World!")
# Out:
# Hello, World! Hello, World! Hello, World!
